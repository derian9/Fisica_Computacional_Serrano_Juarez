# %% [markdown]
# # Tarea 14
#
# ## Sistemas dimámicos dos dimensionales

# %% [markdown]
# __Ejercicio 1: Resolver con Runge-Kutta orden 4 el sistema__
# \begin{align*}
# \dot x &= y-y^3\\
# \dot y &= -x -y^2
# \end{align*}
# * Grafiquen muchas trayectorias en el espacio de fase, utilizando condiciones iniciales aleatorias.
# * Calculen el Jacobiano de $\vec F=\left(y-y^3,-x-y^2 \right)^{\text{T}}$ y evaluenlo en $\vec 0$, el cual es un punto fijo. Calculen $\Delta$ y $\tau$ e indiquen que tipo de punto fijo es el $\vec 0$.

# %%
using PyPlot

# %%
function rk4(f,list,x0) #Definimos Runge-Kutta de orden 4.
     x = x0
     h = list[2]-list[1]
     listx=[]
     push!(listx,x)
     for i in 2:length(list)
        t = i*h
        k1 = f(x,t)
        k2 = f(x+(h/2)*k1,t+(h/2))
        k3 = f(x+(h/2)*k2, t+(h/2))
        k4 = f(x+h*k3, t+h);
        x = x+(h/6)*(k1+2*k2+2*k3+k4)
        push!(listx,x) 
     end
     return listx
end
# Out:
# rk4 (generic function with 1 method)

# %%
A(x,t)=[1*x[2]-1*(x[2])^3,-1*x[1]-1*(x[2])^2] #Definimos nuestra matriz.
listt=0:0.1:30 #Damos un intervalo de tiempo.

for i in 1:1000
    x0=1*(2*rand()-1)
    y0=1*(2*rand()-1)
    listx=map(x->x[1],rk4(A,listt,[x0,y0]))
    listy=map(x->x[2],rk4(A,listt,[x0,y0]))
    
    plot(listx,listy)
end
xlim(-2,2)
ylim(-2,2)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f78f22d19d0>)
# WARNING: Method definition A(Any, Any) in module Main at In[34]:1 overwritten at In[35]:1.
# (-2,2)

# %% [markdown]
# Ahora si queremos calcular el jacobiano de $\vec F=\left(\begin{array}{cc} y - y^3 \\-x-y^2 \end{array} \right)$ sacamos la derivadas parciales.

# %% [markdown]
# $J\vec F=\left(\begin{array}{cc} \frac{\partial }{\partial x}(y - y^3) & \frac{\partial}{\partial y}(y - y^3)  \\ \frac{\partial}{\partial x}(-x-y^2) & \frac{\partial}{\partial y}(-x-y^2)  \end{array} \right)$
# $=$ $\left(\begin{array}{cc} 0 & 1-3y^2  \\ -1 &-2y  \end{array} \right) $ Ahora si lo evaluamos en $\vec 0$.

# %% [markdown]
# $$J\vec F (\vec 0) = \left(\begin{array}{cc} 0 & 1  \\ -1 & 0  \end{array} \right) $$
#
# Podemos notar que $\Delta= \det J\vec F (\vec 0) = 1$, y que $\tau=\text{tr} J\vec F (\vec 0)= 0$. Por lo que el punto $\vec 0$ es un punto centro.

# %% [markdown]
# __Ejercicio 2: Resolver usando Runge-Kutta orden 4 para resolver el oscilador de van der Pol:__
# $${d^2x \over dt^2}-\mu(1-x^2){dx \over dt}+x= 0$$
# * Graficar muchas trayectorias, construidas a partir de condiciones iniciales aleatorias, en el espacio de fase. Observa alguna estructura en particular?

# %%
f(x,t)=[x[2],-x[1]+x[2]*(1-x[1]^2)] #Definimos nuestra función.
listt2=0:0.1:20 

for i in 1:1000
    x0=1*(2*rand()-1)
    y0=1*(2*rand()-1)
    listx=map(x->x[1],rk4(f,listt2,[x0,y0]))
    listy=map(x->x[2],rk4(f,listt2,[x0,y0]))
    
    plot(listx,listy)
end
xlim(-3,3)
ylim(-3,3)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f061e6e1c50>)
# WARNING: Method definition f(Any, Any) in module Main at In[8]:1 overwritten at In[9]:1.
# (-3,3)

# %%
title("Zoom")
grid("on")
for i in 1:1000
    x0=1*(2*rand()-1)
    y0=1*(2*rand()-1)
    listx=map(x->x[1],rk4(f,listt2,[x0,y0]))
    listy=map(x->x[2],rk4(f,listt2,[x0,y0]))
    
    plot(listx,listy)
end

xlim(-1,1)
ylim(-1,1)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f061df64350>)
# (-1,1)

# %% [markdown]
# __Podemos observar una especie de espirales que van convergiendo al origen!.__

# %% [markdown]
# * Usen $\mu=0.5$.
# * Grafiquen varias trayectorias en los espacios $(x,t)$ y $(y=\dot x,t)$.

# %%
f2(x,t)=[x[2],-x[1]+x[2]*0.5*(1-x[1]^2)] #Definimos nuestra función con mu=0.5.
listt3=0:0.1:20
for i in 1:1000
    x0=1*(2*rand()-1)
    y0=1*(2*rand()-1)
    listx=map(x->x[1],rk4(f2,listt3,[x0,y0]))
    listy=map(x->x[2],rk4(f2,listt3,[x0,y0]))
    
    plot(listx,listy)
end
xlim(-3,3)
ylim(-3,3)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f2f19ae9290>)
# WARNING: Method definition f2(Any, Any) in module Main at In[3]:1 overwritten at In[4]:1.
# (-3,3)

# %% [markdown]
# Aqui notamos como las espirales se hacen más redondas que en el caso anterior que tenian la forma similar a la de un cacahuate.

# %%
f2(x,t)=[x[2],-x[1]+x[2]*0.5*(1-x[1]^2)] #Ahora graficamos el espacio x(t) contra t.
listt3=0:0.1:20
for i in 1:5 #Reducimos las iteraciones para observar mejor lo que sucede.
    x0=1*(2*rand()-1)
    y0=1*(2*rand()-1)
    listx=map(x->x[1],rk4(f2,listt3,[x0,y0]))
    listy=map(x->x[2],rk4(f2,listt3,[x0,y0]))
    
    plot(listx,listt3) #Graficamos (x(t),t).
end
title("(x(t),t)")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f5b4a6f0f50>)
# WARNING: Method definition f2(Any, Any) in module Main at In[15]:1 overwritten at In[16]:1.
# PyObject <matplotlib.text.Text object at 0x7f5b4bc341d0>

# %%
f2(x,t)=[x[2],-x[1]+x[2]*0.5*(1-x[1]^2)] #Ahora graficamos el espacio x'(t) contra t.
listt3=0:0.1:10
for i in 1:10 #Reducimos las iteraciones para observar mejor lo que sucede.
    x0=1*(2*rand()-1)
    y0=1*(2*rand()-1)
    listx=map(x->x[1],rk4(f2,listt3,[x0,y0]))
    listy=map(x->x[2],rk4(f2,listt3,[x0,y0]))
    
    plot(listy,listt3) #Graficamos (x'(t),t).
end
title("(x'(t),t)")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f5b4b695a50>)
# WARNING: Method definition f2(Any, Any) in module Main at In[18]:1 overwritten at In[19]:1.
# PyObject <matplotlib.text.Text object at 0x7f5b4b653b90>

# %% [markdown]
# __Ejercicio 4: Hacer lo mismo para el sistema__
# \begin{align*}
# \dot x&= x+y-x (x^2+y^2)\\
# \dot y &= y-x-y(x^2+y^2)
# \end{align*}
# Y comprobar numéricamente que hay un repulsor en $(0,0)$ y un ciclo límite (conjunto atractor) en $x^2+y^2=1$, para cotejar con lo que vimos en clase.

# %%
A2(x,t)=[x[1]+x[2]-x[1]*((x[1])^2+(x[2])^2),x[2]-x[1]-x[2]*((x[1])^2+(x[2])^2)] #Definimos nuestra matriz.
listt=0:0.1:30 #Damos un intervalo de tiempo.

for i in 1:500
    x0=1*(2*rand()-1)
    y0=1*(2*rand()-1)
    listx2=map(x->x[1],rk4(A2,listt,[x0,y0]))
    listy2=map(x->x[2],rk4(A2,listt,[x0,y0]))
    
    plot(listx2,listy2)
end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f5b49758490>)
# WARNING: Method definition A2(Any, Any) in module Main at In[28]:1 overwritten at In[29]:1.

# %%
A2(x,t)=[x[1]+x[2]-x[1]*((x[1])^2+(x[2])^2),x[2]-x[1]-x[2]*((x[1])^2+(x[2])^2)] #Definimos nuestra matriz.
listt=0:0.1:30 #Damos un intervalo de tiempo.

for i in 1:500
    x0=1*(2*rand()-1)
    y0=1*(2*rand()-1)
    listx2=map(x->x[1],rk4(A2,listt,[x0,y0]))
    listy2=map(x->x[2],rk4(A2,listt,[x0,y0]))
    
    plot(listx2,listy2)
end
plot(cos.(listt),sin.(listt),color="black") #Graficamos el ciclo límite.
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f5b4a01e5d0>)
# WARNING: Method definition A2(Any, Any) in module Main at In[38]:1 overwritten at In[46]:1.
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f5b4554f4d0>

# %% [markdown]
# De esta forma podemos ver que hay un ciclo límite en $x^2+y^2=1$.
#
# Ahora para saber si $(0,0)$ es repulsor (y $x^2+y^2=1$ es conjunto atractor) graficamos x(t) contra t.

# %%
for i in 1:5
    x0=1*(2*rand()-1)
    y0=1*(2*rand()-1)
    listx=map(x->x[1],rk4(A2,listt,[x0,y0]))
    listy=map(x->x[2],rk4(A2,listt,[x0,y0]))
    
    plot(listt,listy)
end
title("t,x(t)")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f5b438c3950>)
# PyObject <matplotlib.text.Text object at 0x7f5b438e3750>

# %% [markdown]
# Aqui podemos ver como $(0,0)$ es realmente un repulsor!
